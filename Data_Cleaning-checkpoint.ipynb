# %% [markdown]
# ### Import the libraries

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ### Read the dataset from your device

# %%
df= pd.read_csv("C:/Users/Manisha/Documents/BL-Flickr-Images-Book.csv")

# %% [markdown]
# ### Print the 10 top rows

# %%
df.head(10)
# Out:
#    Identifier              Edition Statement  \
# 0         206                            NaN
# 1         216                            NaN
# 2         218                            NaN
# 3         472                            NaN
# 4         480   A new edition, revised, etc.
# 5         481  Fourth edition, revised, etc.
# 6         519                            NaN
# 7         667                            NaN
# 8         874                            NaN
# 9        1143                            NaN
#
#                   Place of Publication Date of Publication  \
# 0                               London         1879 [1878]
# 1             London; Virtue & Yorston                1868
# 2                               London                1869
# 3                               London                1851
# 4                               London                1857
# 5                               London                1875
# ...

# %% [markdown]
# ### Drop the empty columns in the dataset

# %%
c_drop=["Corporate Author",
       "Corporate Contributors",
       "Former owner",
       "Engraver"
      ]
df.drop(columns=c_drop, inplace=True)

# %%
df
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %%
#analysing series Edition Statement
df["Edition Statement"].head(40)
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                          A new edition, revised, etc.
# 5                         Fourth edition, revised, etc.
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# ...

# %%
#checking the null/nan values for the entire dataset
df.isnull().sum()
# Out:
# Identifier                 0
# Edition Statement       7514
# Place of Publication       0
# Date of Publication      181
# Publisher               4195
# Title                      0
# Author                  1778
# Contributors               0
# Issuance type              0
# Flickr URL                 0
# Shelfmarks                 0
# dtype: int64

# %%
#droping the Edition Statement column
#Edition Statement contain 7514 null values out of 8287
df.drop('Edition Statement', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Identifier                 0
# Place of Publication       0
# Date of Publication      181
# Publisher               4195
# Title                      0
# Author                  1778
# Contributors               0
# Issuance type              0
# Flickr URL                 0
# Shelfmarks                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Identifier               int64
# Place of Publication    object
# Date of Publication     object
# Publisher               object
# Title                   object
# Author                  object
# Contributors            object
# Issuance type           object
# Flickr URL              object
# Shelfmarks              object
# dtype: object

# %%
df["Identifier"].is_unique
# Out:
# True

# %%
#changing the index to unique value 
#chnaging index to identifier column
df.set_index("Identifier", inplace=True)

# %%
df.loc[:, "Date of Publication"].head(40)
# Out:
# Identifier
# 206             1879 [1878]
# 216                    1868
# 218                    1869
# 472                    1851
# 480                    1857
# 481                    1875
# 519                    1872
# 667                     NaN
# 874                    1676
# 1143                   1679
# 1280                   1802
# 1808                   1859
# 1905                   1888
# 1929            1839, 38-54
# 2836                   1897
# 2854                   1865
# 2956                1860-63
# 2957                   1873
# 3017                   1866
# 3131                   1899
# 4598                   1814
# 4884                   1820
# 4976                   1800
# 5382     1847, 48 [1846-48]
# 5385                [1897?]
# 5389                [1897?]
# 5432                   1893
# 6036                   1805
# 6821                   1837
# 7521                   1896
# 7630                   1898
# 8239                   1899
# ...

# %%
#transfoming all values to same format in Date of Publication column
extr= df["Date of Publication"].str.extract(r'^(\d{4})', expand=False)

# %%
extr.head(40)
# Out:
# Identifier
# 206      1879
# 216      1868
# 218      1869
# 472      1851
# 480      1857
# 481      1875
# 519      1872
# 667       NaN
# 874      1676
# 1143     1679
# 1280     1802
# 1808     1859
# 1905     1888
# 1929     1839
# 2836     1897
# 2854     1865
# 2956     1860
# 2957     1873
# 3017     1866
# 3131     1899
# 4598     1814
# 4884     1820
# 4976     1800
# 5382     1847
# 5385      NaN
# 5389      NaN
# 5432     1893
# 6036     1805
# 6821     1837
# 7521     1896
# 7630     1898
# 8239     1899
# 8435     1892
# 8440     1894
# 11361     NaN
# 11852     NaN
# 13074    1899
# 13364     NaN
# 14466     NaN
# 14703    1846
# Name: Date of Publication, dtype: object

# %%
df["Date of Publication"]= df["Date of Publication"]=pd.to_numeric(extr)

# %%
df["Date of Publication"].dtype
# Out:
# dtype('float64')

# %%
df.head(40)
# Out:
#                            Place of Publication  Date of Publication  \
# Identifier
# 206                                      London               1879.0
# 216                    London; Virtue & Yorston               1868.0
# 218                                      London               1869.0
# 472                                      London               1851.0
# 480                                      London               1857.0
# 481                                      London               1875.0
# 519                                      London               1872.0
# 667         pp. 40. G. Bryan & Co: Oxford, 1898                  NaN
# 874                                     London]               1676.0
# 1143                                     London               1679.0
# 1280                                   Coventry               1802.0
# 1808                                Christiania               1859.0
# ...

# %%
df['Date of Publication'].isnull().sum()/len(df)
# Out:
# 0.11717147339205986

# %%
df
# Out:
#                 Place of Publication  Date of Publication  \
# Identifier
# 206                           London               1879.0
# 216         London; Virtue & Yorston               1868.0
# 218                           London               1869.0
# 472                           London               1851.0
# 480                           London               1857.0
# ...                              ...                  ...
# 4158088                       London               1838.0
# 4158128                        Derby               1831.0
# 4159563                       London                  NaN
# 4159587          Newcastle upon Tyne               1834.0
# 4160339                       London               1834.0
#
#                           Publisher  \
# Identifier
# 206                S. Tinsley & Co.
# 216                    Virtue & Co.
# 218           Bradbury, Evans & Co.
# 472                   James Darling
# 480            Wertheim & Macintosh
# ...

# %%
df['Place of Publication'].head(40)
# Out:
# Identifier
# 206                                   London
# 216                 London; Virtue & Yorston
# 218                                   London
# 472                                   London
# 480                                   London
# 481                                   London
# 519                                   London
# 667      pp. 40. G. Bryan & Co: Oxford, 1898
# 874                                  London]
# 1143                                  London
# 1280                                Coventry
# 1808                             Christiania
# 1905                                 Firenze
# 1929                               Amsterdam
# 2836                                  Savona
# 2854                                  London
# 2956                                   Paris
# 2957                                   Paris
# 3017                             Puerto-Rico
# 3131                                New York
# 4598                                    Hull
# ...

# %%
df.loc[4157862:]
# Out:
#            Place of Publication  Date of Publication                Publisher  \
# Identifier
# 4157862     Newcastle-upon-Tyne               1867.0               T. Fordyce
# 4158088                  London               1838.0                      NaN
# 4158128                   Derby               1831.0          M. Mozley & Son
# 4159563                  London                  NaN  T. Cadell and W. Davies
# 4159587     Newcastle upon Tyne               1834.0         Mackenzie & Dent
# 4160339                  London               1834.0                      NaN
#
#                                                         Title  \
# Identifier
# 4157862     Local Records; or, Historical Register of rema...
# 4158088     The Parochial History of Cornwall, founded on,...
# 4158128     The History and Gazetteer of the County of Der...
# 4159563     Magna Britannia; being a concise topographical...
# 4159587     An historical, topographical and descriptive v...
# ...

# %%
#cleaning the country names to have same fomat
clean=df["Place of Publication"]
London=clean.str.contains("London")
Oxford=clean.str.contains("Oxford")

# %%
London[:10]
# Out:
# Identifier
# 206      True
# 216      True
# 218      True
# 472      True
# 480      True
# 481      True
# 519      True
# 667     False
# 874      True
# 1143     True
# Name: Place of Publication, dtype: bool

# %%
#replacing the extra characters
df["Place of Publication"]=np.where(London,'London',
                                    np.where(Oxford,'Oxford',
                                            clean.str.replace("-", " ")))

# %%
df['Place of Publication'].head(40)
# Out:
# Identifier
# 206                                  London
# 216                                  London
# 218                                  London
# 472                                  London
# 480                                  London
# 481                                  London
# 519                                  London
# 667                                  Oxford
# 874                                  London
# 1143                                 London
# 1280                               Coventry
# 1808                            Christiania
# 1905                                Firenze
# 1929                              Amsterdam
# 2836                                 Savona
# 2854                                 London
# 2956                                  Paris
# 2957                                  Paris
# 3017                            Puerto Rico
# 3131                               New York
# 4598                                   Hull
# ...

# %%
df['Place of Publication']
# Out:
# Identifier
# 206                     London
# 216                     London
# 218                     London
# 472                     London
# 480                     London
#                   ...
# 4158088                 London
# 4158128                  Derby
# 4159563                 London
# 4159587    Newcastle upon Tyne
# 4160339                 London
# Name: Place of Publication, Length: 8287, dtype: object

# %%
df
# Out:
#            Place of Publication  Date of Publication                Publisher  \
# Identifier
# 206                      London               1879.0         S. Tinsley & Co.
# 216                      London               1868.0             Virtue & Co.
# 218                      London               1869.0    Bradbury, Evans & Co.
# 472                      London               1851.0            James Darling
# 480                      London               1857.0     Wertheim & Macintosh
# ...                         ...                  ...                      ...
# 4158088                  London               1838.0                      NaN
# 4158128                   Derby               1831.0          M. Mozley & Son
# 4159563                  London                  NaN  T. Cadell and W. Davies
# 4159587     Newcastle upon Tyne               1834.0         Mackenzie & Dent
# 4160339                  London               1834.0                      NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Place of Publication       0
# Date of Publication      971
# Publisher               4195
# Title                      0
# Author                  1778
# Contributors               0
# Issuance type              0
# Flickr URL                 0
# Shelfmarks                 0
# dtype: int64

# %%
#fill the nan/null values in Date of Publication column with forward fill
df['Date of Publication'].ffill(inplace=True)

# %%
df["Date of Publication"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Place of Publication       0
# Date of Publication        0
# Publisher               4195
# Title                      0
# Author                  1778
# Contributors               0
# Issuance type              0
# Flickr URL                 0
# Shelfmarks                 0
# dtype: int64

# %%
#full the entire nan/null values in dataset
df = df.fillna(df.mode().iloc[0])
print(df.isnull().sum())
# Out:
# Place of Publication    0
# Date of Publication     0
# Publisher               0
# Title                   0
# Author                  0
# Contributors            0
# Issuance type           0
# Flickr URL              0
# Shelfmarks              0
# dtype: int64

# %%
#replace the numeric values from the Place of Publication column
df['Place of Publication'] = df['Place of Publication'].str.replace('\d+', '')
# Out:
# C:\Users\Manisha\AppData\Local\Temp\ipykernel_7612\3251756039.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Place of Publication'] = df['Place of Publication'].str.replace('\d+', '')

# %%
df.head(40)
# Out:
#                     Place of Publication  Date of Publication  \
# Identifier
# 206                               London               1879.0
# 216                               London               1868.0
# 218                               London               1869.0
# 472                               London               1851.0
# 480                               London               1857.0
# 481                               London               1875.0
# 519                               London               1872.0
# 667                               Oxford               1872.0
# 874                               London               1676.0
# 1143                              London               1679.0
# 1280                            Coventry               1802.0
# 1808                         Christiania               1859.0
# 1905                             Firenze               1888.0
# 1929                           Amsterdam               1839.0
# ...

# %%
#replace the nan with 'unknown' 
df['Place of Publication'].fillna('unknown', inplace=True)

# %%
df
# Out:
#            Place of Publication  Date of Publication                Publisher  \
# Identifier
# 206                      London               1879.0         S. Tinsley & Co.
# 216                      London               1868.0             Virtue & Co.
# 218                      London               1869.0    Bradbury, Evans & Co.
# 472                      London               1851.0            James Darling
# 480                      London               1857.0     Wertheim & Macintosh
# ...                         ...                  ...                      ...
# 4158088                  London               1838.0          Macmillan & Co.
# 4158128                   Derby               1831.0          M. Mozley & Son
# 4159563                  London               1831.0  T. Cadell and W. Davies
# 4159587     Newcastle upon Tyne               1834.0         Mackenzie & Dent
# 4160339                  London               1834.0          Macmillan & Co.
#
# ...

# %%
df.fillna({'Place of Publication':'unknown', 'Publisher':'unknown','Title':'unknown','Author':'unknown','Contributors':'unknown','Issuance type':'unknown'})
# Out:
#            Place of Publication  Date of Publication                Publisher  \
# Identifier
# 206                      London               1879.0         S. Tinsley & Co.
# 216                      London               1868.0             Virtue & Co.
# 218                      London               1869.0    Bradbury, Evans & Co.
# 472                      London               1851.0            James Darling
# 480                      London               1857.0     Wertheim & Macintosh
# ...                         ...                  ...                      ...
# 4158088                  London               1838.0          Macmillan & Co.
# 4158128                   Derby               1831.0          M. Mozley & Son
# 4159563                  London               1831.0  T. Cadell and W. Davies
# 4159587     Newcastle upon Tyne               1834.0         Mackenzie & Dent
# 4160339                  London               1834.0          Macmillan & Co.
#
# ...

# %%
df.head(40)
# Out:
#                     Place of Publication  Date of Publication  \
# Identifier
# 206                               London               1879.0
# 216                               London               1868.0
# 218                               London               1869.0
# 472                               London               1851.0
# 480                               London               1857.0
# 481                               London               1875.0
# 519                               London               1872.0
# 667                               Oxford               1872.0
# 874                               London               1676.0
# 1143                              London               1679.0
# 1280                            Coventry               1802.0
# 1808                         Christiania               1859.0
# 1905                             Firenze               1888.0
# 1929                           Amsterdam               1839.0
# ...
